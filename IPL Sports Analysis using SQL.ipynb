# %%
import numpy as np
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect("D:\\PORTFOLIO PROJECTS\\New folder\\database.sqlite")

# %%
c = conn.cursor()

# %%
c.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = c.fetchall()
# Print the table names
for table in tables:
    print(table[0])
# Out:
# Player
# Extra_Runs
# Batsman_Scored
# Batting_Style
# Bowling_Style
# Country
# Season
# City
# Outcome
# Win_By
# Wicket_Taken
# Venue
# Extra_Type
# Out_Type
# Toss_Decision
# Umpire
# Team
# Ball_by_Ball
# sysdiagrams
# sqlite_sequence
# Match
# Rolee
# Player_Match

# %% [markdown]
# ###### Solving business questions for the database of IPL Sports Analysis

# %%
#1.Number of matches played in each stadium
sql=""" SELECT ve.Venue_Id, ve.Venue_Name, COUNT(ma.Outcome_type) AS No_of_match_played, ci.City_Name AS Location
FROM Venue ve
JOIN Match ma ON ve.Venue_Id = ma.Venue_Id
JOIN City ci ON ve.City_Id = ci.City_Id
GROUP BY ve.Venue_Id, ve.Venue_Name,ci.City_Name
ORDER BY COUNT(ma.Outcome_type) DESC;
"""
No_of_match_played=pd.read_sql(sql,conn)
No_of_match_played.head(5).style.background_gradient(subset=["No_of_match_played"], cmap='Blues',low=0.55)
# Out:
# <style type="text/css">
# #T_a4e83_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a4e83_row1_col2 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_a4e83_row2_col2 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_a4e83_row3_col2 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_a4e83_row4_col2 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# </style>
# <table id="T_a4e83_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Venue_Id</th>
#       <th class="col_heading level0 col1" >Venue_Name</th>
#       <th class="col_heading level0 col2" >No_of_match_played</th>
#       <th class="col_heading level0 col3" >Location</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4e83_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4e83_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a4e83_row0_col1" class="data row0 col1" >M Chinnaswamy Stadium</td>
#       <td id="T_a4e83_row0_col2" class="data row0 col2" >58</td>
#       <td id="T_a4e83_row0_col3" class="data row0 col3" >Bangalore</td>
#     </tr>
#     <tr>
#       <th id="T_a4e83_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a4e83_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_a4e83_row1_col1" class="data row1 col1" >Eden Gardens</td>
#       <td id="T_a4e83_row1_col2" class="data row1 col2" >54</td>
#       <td id="T_a4e83_row1_col3" class="data row1 col3" >Kolkata</td>
#     </tr>
#     <tr>
#       <th id="T_a4e83_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a4e83_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_a4e83_row2_col1" class="data row2 col1" >Feroz Shah Kotla</td>
#       <td id="T_a4e83_row2_col2" class="data row2 col2" >53</td>
#       <td id="T_a4e83_row2_col3" class="data row2 col3" >Delhi</td>
#     </tr>
#     <tr>
#       <th id="T_a4e83_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a4e83_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_a4e83_row3_col1" class="data row3 col1" >Wankhede Stadium</td>
#       <td id="T_a4e83_row3_col2" class="data row3 col2" >49</td>
#       <td id="T_a4e83_row3_col3" class="data row3 col3" >Mumbai</td>
#     </tr>
#     <tr>
#       <th id="T_a4e83_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a4e83_row4_col0" class="data row4 col0" >8</td>
#       <td id="T_a4e83_row4_col1" class="data row4 col1" >MA Chidambaram Stadium, Chepauk</td>
#       <td id="T_a4e83_row4_col2" class="data row4 col2" >48</td>
#       <td id="T_a4e83_row4_col3" class="data row4 col3" >Chennai</td>
#     </tr>
#   </tbody>
# </table>

# %%
#2.What is the average number of runs scored in each season?
sql=""" SELECT se.Season_Id,se.Season_Year,ROUND(AVG(ba.Runs_Scored)*100) AS AVG_Runs
FROM Batsman_Scored ba
JOIN Match me 
ON me.Match_Id=ba.Match_Id
JOIN Season se
ON me.Season_Id=se.Season_Id
GROUP BY se.Season_Id,se.Season_Year
ORDER BY se.Season_Year DESC;
"""
AVG_Runs=pd.read_sql(sql,conn)
AVG_Runs.style.background_gradient(subset=["AVG_Runs"], cmap='Blues_r',low=0.55)
# Out:
# <style type="text/css">
# #T_c18dc_row0_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_c18dc_row1_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c18dc_row2_col2, #T_c18dc_row8_col2 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_c18dc_row3_col2, #T_c18dc_row4_col2 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_c18dc_row5_col2 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_c18dc_row6_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_c18dc_row7_col2 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c18dc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Season_Id</th>
#       <th class="col_heading level0 col1" >Season_Year</th>
#       <th class="col_heading level0 col2" >AVG_Runs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c18dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c18dc_row0_col0" class="data row0 col0" >9</td>
#       <td id="T_c18dc_row0_col1" class="data row0 col1" >2016</td>
#       <td id="T_c18dc_row0_col2" class="data row0 col2" >131.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c18dc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c18dc_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_c18dc_row1_col1" class="data row1 col1" >2015</td>
#       <td id="T_c18dc_row1_col2" class="data row1 col2" >132.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c18dc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c18dc_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_c18dc_row2_col1" class="data row2 col1" >2014</td>
#       <td id="T_c18dc_row2_col2" class="data row2 col2" >129.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c18dc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c18dc_row3_col0" class="data row3 col0" >6</td>
#       <td id="T_c18dc_row3_col1" class="data row3 col1" >2013</td>
#       <td id="T_c18dc_row3_col2" class="data row3 col2" >120.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c18dc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c18dc_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_c18dc_row4_col1" class="data row4 col1" >2012</td>
#       <td id="T_c18dc_row4_col2" class="data row4 col2" >120.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c18dc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c18dc_row5_col0" class="data row5 col0" >4</td>
#       <td id="T_c18dc_row5_col1" class="data row5 col1" >2011</td>
#       <td id="T_c18dc_row5_col2" class="data row5 col2" >121.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c18dc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c18dc_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_c18dc_row6_col1" class="data row6 col1" >2010</td>
#       <td id="T_c18dc_row6_col2" class="data row6 col2" >127.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c18dc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c18dc_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_c18dc_row7_col1" class="data row7 col1" >2009</td>
#       <td id="T_c18dc_row7_col2" class="data row7 col2" >117.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c18dc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c18dc_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_c18dc_row8_col1" class="data row8 col1" >2008</td>
#       <td id="T_c18dc_row8_col2" class="data row8 col2" >129.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#3.Number of matches played in each city¶
sql=""" SELECT ce.City_Name,SUM(me.Outcome_type) AS No_Of_Matches
FROM City ce
JOIN Venue ve ON ve.City_Id=ce.City_Id
JOIN Match me ON me.Venue_Id=ve.Venue_Id
GROUP BY ce.City_Name
ORDER BY COUNT(me.Outcome_type) DESC;
"""
No_Of_Matches=pd.read_sql(sql,conn)
No_Of_Matches.head().style.background_gradient(subset=["No_Of_Matches"], cmap='Blues',low=0.55)
# Out:
# <style type="text/css">
# #T_cd1ed_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cd1ed_row1_col1 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_cd1ed_row2_col1, #T_cd1ed_row3_col1 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_cd1ed_row4_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# </style>
# <table id="T_cd1ed_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >City_Name</th>
#       <th class="col_heading level0 col1" >No_Of_Matches</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd1ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd1ed_row0_col0" class="data row0 col0" >Mumbai</td>
#       <td id="T_cd1ed_row0_col1" class="data row0 col1" >77</td>
#     </tr>
#     <tr>
#       <th id="T_cd1ed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd1ed_row1_col0" class="data row1 col0" >Bangalore</td>
#       <td id="T_cd1ed_row1_col1" class="data row1 col1" >62</td>
#     </tr>
#     <tr>
#       <th id="T_cd1ed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cd1ed_row2_col0" class="data row2 col0" >Kolkata</td>
#       <td id="T_cd1ed_row2_col1" class="data row2 col1" >54</td>
#     </tr>
#     <tr>
#       <th id="T_cd1ed_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cd1ed_row3_col0" class="data row3 col0" >Delhi</td>
#       <td id="T_cd1ed_row3_col1" class="data row3 col1" >54</td>
#     </tr>
#     <tr>
#       <th id="T_cd1ed_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cd1ed_row4_col0" class="data row4 col0" >Chennai</td>
#       <td id="T_cd1ed_row4_col1" class="data row4 col1" >50</td>
#     </tr>
#   </tbody>
# </table>

# %%
#4.Top 10 wicket takers¶
sql = """
select pe.player_name, COUNT(wt.Kind_Out) Total_Wickets
from Wicket_taken wt
JOIN Ball_by_ball bl
ON wt.Match_id = bl.Match_Id
   AND wt.Over_id = bl.Over_id
   AND wt.ball_id = bl.ball_id
   AND wt.Innings_No = bl.Innings_No
JOIN player pe
ON pe.player_id = bl.bowler

Group by bl.bowler
ORDER BY COUNT(wt.Kind_Out) DESC
LIMIT 10
"""
wicket_takers = pd.read_sql(sql, conn)
wicket_takers.style.background_gradient(subset=["Total_Wickets"], cmap='Greens',low=0.55)
# Out:
# <style type="text/css">
# #T_ceb2a_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_ceb2a_row1_col1 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_ceb2a_row2_col1 {
#   background-color: #2e964d;
#   color: #f1f1f1;
# }
# #T_ceb2a_row3_col1 {
#   background-color: #38a156;
#   color: #f1f1f1;
# }
# #T_ceb2a_row4_col1 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_ceb2a_row5_col1 {
#   background-color: #48ae60;
#   color: #f1f1f1;
# }
# #T_ceb2a_row6_col1 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_ceb2a_row7_col1 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_ceb2a_row8_col1 {
#   background-color: #8dd08a;
#   color: #000000;
# }
# #T_ceb2a_row9_col1 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# </style>
# <table id="T_ceb2a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Total_Wickets</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ceb2a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ceb2a_row0_col0" class="data row0 col0" >SL Malinga</td>
#       <td id="T_ceb2a_row0_col1" class="data row0 col1" >159</td>
#     </tr>
#     <tr>
#       <th id="T_ceb2a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ceb2a_row1_col0" class="data row1 col0" >DJ Bravo</td>
#       <td id="T_ceb2a_row1_col1" class="data row1 col1" >137</td>
#     </tr>
#     <tr>
#       <th id="T_ceb2a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ceb2a_row2_col0" class="data row2 col0" >A Mishra</td>
#       <td id="T_ceb2a_row2_col1" class="data row2 col1" >132</td>
#     </tr>
#     <tr>
#       <th id="T_ceb2a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ceb2a_row3_col0" class="data row3 col0" >Harbhajan Singh</td>
#       <td id="T_ceb2a_row3_col1" class="data row3 col1" >128</td>
#     </tr>
#     <tr>
#       <th id="T_ceb2a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ceb2a_row4_col0" class="data row4 col0" >PP Chawla</td>
#       <td id="T_ceb2a_row4_col1" class="data row4 col1" >127</td>
#     </tr>
#     <tr>
#       <th id="T_ceb2a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ceb2a_row5_col0" class="data row5 col0" >R Vinay Kumar</td>
#       <td id="T_ceb2a_row5_col1" class="data row5 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ceb2a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ceb2a_row6_col0" class="data row6 col0" >A Nehra</td>
#       <td id="T_ceb2a_row6_col1" class="data row6 col1" >111</td>
#     </tr>
#     <tr>
#       <th id="T_ceb2a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ceb2a_row7_col0" class="data row7 col0" >R Ashwin</td>
#       <td id="T_ceb2a_row7_col1" class="data row7 col1" >110</td>
#     </tr>
#     <tr>
#       <th id="T_ceb2a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ceb2a_row8_col0" class="data row8 col0" >Z Khan</td>
#       <td id="T_ceb2a_row8_col1" class="data row8 col1" >107</td>
#     </tr>
#     <tr>
#       <th id="T_ceb2a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ceb2a_row9_col0" class="data row9 col0" >DW Steyn</td>
#       <td id="T_ceb2a_row9_col1" class="data row9 col1" >100</td>
#     </tr>
#   </tbody>
# </table>

# %%
#5.No of players in the IPL country wise
sql="""
SELECT co.Country_Id,co.Country_Name,COUNT(pl.Player_Name) as No_Of_Players_country_wise
FROM Player pl
JOIN Country co
ON co.Country_Id=pl.Country_Name
GROUP BY co.Country_Id,co.Country_Name
ORDER BY SUM(pl.Player_Name) DESC;
"""
No_Of_Players=pd.read_sql(sql,conn)
No_Of_Players.style.background_gradient(subset=["No_Of_Players_country_wise"], cmap='Greys',low=0.55)
# Out:
# <style type="text/css">
# #T_ef965_row0_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ef965_row1_col2 {
#   background-color: #a7a7a7;
#   color: #f1f1f1;
# }
# #T_ef965_row2_col2 {
#   background-color: #b3b3b3;
#   color: #000000;
# }
# #T_ef965_row3_col2 {
#   background-color: #8e8e8e;
#   color: #f1f1f1;
# }
# #T_ef965_row4_col2 {
#   background-color: #bababa;
#   color: #000000;
# }
# #T_ef965_row5_col2, #T_ef965_row6_col2 {
#   background-color: #b5b5b5;
#   color: #000000;
# }
# #T_ef965_row7_col2 {
#   background-color: #c1c1c1;
#   color: #000000;
# }
# #T_ef965_row8_col2 {
#   background-color: #b9b9b9;
#   color: #000000;
# }
# #T_ef965_row9_col2 {
#   background-color: #bfbfbf;
#   color: #000000;
# }
# #T_ef965_row10_col2 {
#   background-color: #c2c2c2;
#   color: #000000;
# }
# </style>
# <table id="T_ef965_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Country_Id</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >No_Of_Players_country_wise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef965_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef965_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ef965_row0_col1" class="data row0 col1" >India</td>
#       <td id="T_ef965_row0_col2" class="data row0 col2" >262</td>
#     </tr>
#     <tr>
#       <th id="T_ef965_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ef965_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ef965_row1_col1" class="data row1 col1" >South Africa</td>
#       <td id="T_ef965_row1_col2" class="data row1 col2" >39</td>
#     </tr>
#     <tr>
#       <th id="T_ef965_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ef965_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_ef965_row2_col1" class="data row2 col1" >New Zealand</td>
#       <td id="T_ef965_row2_col2" class="data row2 col2" >22</td>
#     </tr>
#     <tr>
#       <th id="T_ef965_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ef965_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_ef965_row3_col1" class="data row3 col1" >Australia</td>
#       <td id="T_ef965_row3_col2" class="data row3 col2" >72</td>
#     </tr>
#     <tr>
#       <th id="T_ef965_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ef965_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_ef965_row4_col1" class="data row4 col1" >Pakistan</td>
#       <td id="T_ef965_row4_col2" class="data row4 col2" >13</td>
#     </tr>
#     <tr>
#       <th id="T_ef965_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ef965_row5_col0" class="data row5 col0" >7</td>
#       <td id="T_ef965_row5_col1" class="data row5 col1" >Sri Lanka</td>
#       <td id="T_ef965_row5_col2" class="data row5 col2" >20</td>
#     </tr>
#     <tr>
#       <th id="T_ef965_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ef965_row6_col0" class="data row6 col0" >8</td>
#       <td id="T_ef965_row6_col1" class="data row6 col1" >West Indies</td>
#       <td id="T_ef965_row6_col2" class="data row6 col2" >19</td>
#     </tr>
#     <tr>
#       <th id="T_ef965_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ef965_row7_col0" class="data row7 col0" >9</td>
#       <td id="T_ef965_row7_col1" class="data row7 col1" >Zimbabwea</td>
#       <td id="T_ef965_row7_col2" class="data row7 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ef965_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ef965_row8_col0" class="data row8 col0" >10</td>
#       <td id="T_ef965_row8_col1" class="data row8 col1" >England</td>
#       <td id="T_ef965_row8_col2" class="data row8 col2" >14</td>
#     </tr>
#     <tr>
#       <th id="T_ef965_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ef965_row9_col0" class="data row9 col0" >11</td>
#       <td id="T_ef965_row9_col1" class="data row9 col1" >Bangladesh</td>
#       <td id="T_ef965_row9_col2" class="data row9 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_ef965_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ef965_row10_col0" class="data row10 col0" >12</td>
#       <td id="T_ef965_row10_col1" class="data row10 col1" >Netherlands</td>
#       <td id="T_ef965_row10_col2" class="data row10 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
#6.Which bowling style has the highest number of wickets
sql="""
SELECT bo.Bowling_skill,COUNT(wt.Kind_Out) AS highest_number_of_wickets
FROM Wicket_Taken wt 
JOIN Ball_by_Ball ba
ON wt.Match_Id=ba.Match_Id
AND wt.Over_Id=ba.Over_Id
AND wt.Ball_Id=ba.Ball_Id
AND wt.Innings_No=ba.Innings_No
JOIN Bowling_Style bo
ON bo.Bowling_Id=ba.Bowler
GROUP BY bo.Bowling_Id
ORDER BY COUNT(wt.Kind_Out) DESC;
"""
highest_number_of_wickets=pd.read_sql(sql,conn)
highest_number_of_wickets.style.background_gradient(subset=["highest_number_of_wickets"],cmap="cubehelix",low=0.25)
# Out:
# <style type="text/css">
# #T_16882_row0_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_16882_row1_col1 {
#   background-color: #c1d1f3;
#   color: #000000;
# }
# #T_16882_row2_col1 {
#   background-color: #1c6344;
#   color: #f1f1f1;
# }
# #T_16882_row3_col1 {
#   background-color: #195d48;
#   color: #f1f1f1;
# }
# #T_16882_row4_col1 {
#   background-color: #16534c;
#   color: #f1f1f1;
# }
# #T_16882_row5_col1 {
#   background-color: #154b4e;
#   color: #f1f1f1;
# }
# #T_16882_row6_col1 {
#   background-color: #16404e;
#   color: #f1f1f1;
# }
# #T_16882_row7_col1, #T_16882_row8_col1 {
#   background-color: #163d4e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_16882_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Bowling_skill</th>
#       <th class="col_heading level0 col1" >highest_number_of_wickets</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16882_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16882_row0_col0" class="data row0 col0" >Left-arm fast</td>
#       <td id="T_16882_row0_col1" class="data row0 col1" >96</td>
#     </tr>
#     <tr>
#       <th id="T_16882_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16882_row1_col0" class="data row1 col0" >Left-arm medium-fast</td>
#       <td id="T_16882_row1_col1" class="data row1 col1" >74</td>
#     </tr>
#     <tr>
#       <th id="T_16882_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_16882_row2_col0" class="data row2 col0" >Right-arm medium</td>
#       <td id="T_16882_row2_col1" class="data row2 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_16882_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_16882_row3_col0" class="data row3 col0" >Legbreak googly</td>
#       <td id="T_16882_row3_col1" class="data row3 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_16882_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_16882_row4_col0" class="data row4 col0" >Right-arm bowler</td>
#       <td id="T_16882_row4_col1" class="data row4 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_16882_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_16882_row5_col0" class="data row5 col0" >Slow left-arm chinaman</td>
#       <td id="T_16882_row5_col1" class="data row5 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_16882_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_16882_row6_col0" class="data row6 col0" >Right-arm medium-fast</td>
#       <td id="T_16882_row6_col1" class="data row6 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_16882_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_16882_row7_col0" class="data row7 col0" >Left-arm medium</td>
#       <td id="T_16882_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_16882_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_16882_row8_col0" class="data row8 col0" >Legbreak</td>
#       <td id="T_16882_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
#7.Number matches won by each team per year 
sql = """
SELECT  te.Team_Name as Team_Name, se.Season_Year, Count(ma.Match_Winner) AS Number_of_wins
FROM Match ma
JOIN Season se
ON ma.Season_Id=se.Season_Id
JOIN Team te
ON te.Team_Id  = ma.Match_Winner
GROUP BY te.Team_Name,se.Season_Year
ORDER BY Count(ma.Match_Winner) DESC
LIMIT 10
"""
Number_of_wins = pd.read_sql(sql, conn)
Number_of_wins.style.background_gradient(subset=["Number_of_wins"],cmap="copper",low=0.25)
# Out:
# <style type="text/css">
# #T_7d63f_row0_col2, #T_7d63f_row1_col2 {
#   background-color: #ffc77f;
#   color: #000000;
# }
# #T_7d63f_row2_col2, #T_7d63f_row3_col2, #T_7d63f_row4_col2 {
#   background-color: #bd784c;
#   color: #f1f1f1;
# }
# #T_7d63f_row5_col2, #T_7d63f_row6_col2, #T_7d63f_row7_col2, #T_7d63f_row8_col2, #T_7d63f_row9_col2 {
#   background-color: #3f2819;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7d63f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Team_Name</th>
#       <th class="col_heading level0 col1" >Season_Year</th>
#       <th class="col_heading level0 col2" >Number_of_wins</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d63f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d63f_row0_col0" class="data row0 col0" >Mumbai Indians</td>
#       <td id="T_7d63f_row0_col1" class="data row0 col1" >2013</td>
#       <td id="T_7d63f_row0_col2" class="data row0 col2" >13</td>
#     </tr>
#     <tr>
#       <th id="T_7d63f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d63f_row1_col0" class="data row1 col0" >Rajasthan Royals</td>
#       <td id="T_7d63f_row1_col1" class="data row1 col1" >2008</td>
#       <td id="T_7d63f_row1_col2" class="data row1 col2" >13</td>
#     </tr>
#     <tr>
#       <th id="T_7d63f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d63f_row2_col0" class="data row2 col0" >Chennai Super Kings</td>
#       <td id="T_7d63f_row2_col1" class="data row2 col1" >2013</td>
#       <td id="T_7d63f_row2_col2" class="data row2 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_7d63f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d63f_row3_col0" class="data row3 col0" >Kings XI Punjab</td>
#       <td id="T_7d63f_row3_col1" class="data row3 col1" >2014</td>
#       <td id="T_7d63f_row3_col2" class="data row3 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_7d63f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7d63f_row4_col0" class="data row4 col0" >Kolkata Knight Riders</td>
#       <td id="T_7d63f_row4_col1" class="data row4 col1" >2012</td>
#       <td id="T_7d63f_row4_col2" class="data row4 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_7d63f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7d63f_row5_col0" class="data row5 col0" >Chennai Super Kings</td>
#       <td id="T_7d63f_row5_col1" class="data row5 col1" >2011</td>
#       <td id="T_7d63f_row5_col2" class="data row5 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_7d63f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7d63f_row6_col0" class="data row6 col0" >Delhi Daredevils</td>
#       <td id="T_7d63f_row6_col1" class="data row6 col1" >2012</td>
#       <td id="T_7d63f_row6_col2" class="data row6 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_7d63f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7d63f_row7_col0" class="data row7 col0" >Kolkata Knight Riders</td>
#       <td id="T_7d63f_row7_col1" class="data row7 col1" >2014</td>
#       <td id="T_7d63f_row7_col2" class="data row7 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_7d63f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7d63f_row8_col0" class="data row8 col0" >Mumbai Indians</td>
#       <td id="T_7d63f_row8_col1" class="data row8 col1" >2010</td>
#       <td id="T_7d63f_row8_col2" class="data row8 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_7d63f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7d63f_row9_col0" class="data row9 col0" >Rajasthan Royals</td>
#       <td id="T_7d63f_row9_col1" class="data row9 col1" >2013</td>
#       <td id="T_7d63f_row9_col2" class="data row9 col2" >11</td>
#     </tr>
#   </tbody>
# </table>

# %%
#8.Total matches won by each team
sql = """
SELECT  te.Team_Name as Team_Name,Count(ma.Match_Winner) AS Matches
FROM Match ma
JOIN Team te
ON te.Team_Id  = ma.Match_Winner
GROUP BY te.Team_Name
ORDER BY Count(ma.Match_Winner) DESC
LIMIT 10
"""
Matches = pd.read_sql(sql, conn)
Matches.style.background_gradient(subset=["Matches"],cmap="summer",low=0.25)
# Out:
# <style type="text/css">
# #T_f2bfa_row0_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_f2bfa_row1_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_f2bfa_row2_col1 {
#   background-color: #e1f066;
#   color: #000000;
# }
# #T_f2bfa_row3_col1 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_f2bfa_row4_col1, #T_f2bfa_row5_col1 {
#   background-color: #cce666;
#   color: #000000;
# }
# #T_f2bfa_row6_col1 {
#   background-color: #b7db66;
#   color: #000000;
# }
# #T_f2bfa_row7_col1 {
#   background-color: #75ba66;
#   color: #f1f1f1;
# }
# #T_f2bfa_row8_col1 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_f2bfa_row9_col1 {
#   background-color: #339966;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f2bfa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Team_Name</th>
#       <th class="col_heading level0 col1" >Matches</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2bfa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2bfa_row0_col0" class="data row0 col0" >Mumbai Indians</td>
#       <td id="T_f2bfa_row0_col1" class="data row0 col1" >80</td>
#     </tr>
#     <tr>
#       <th id="T_f2bfa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f2bfa_row1_col0" class="data row1 col0" >Chennai Super Kings</td>
#       <td id="T_f2bfa_row1_col1" class="data row1 col1" >79</td>
#     </tr>
#     <tr>
#       <th id="T_f2bfa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f2bfa_row2_col0" class="data row2 col0" >Royal Challengers Bangalore</td>
#       <td id="T_f2bfa_row2_col1" class="data row2 col1" >70</td>
#     </tr>
#     <tr>
#       <th id="T_f2bfa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f2bfa_row3_col0" class="data row3 col0" >Kolkata Knight Riders</td>
#       <td id="T_f2bfa_row3_col1" class="data row3 col1" >68</td>
#     </tr>
#     <tr>
#       <th id="T_f2bfa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f2bfa_row4_col0" class="data row4 col0" >Rajasthan Royals</td>
#       <td id="T_f2bfa_row4_col1" class="data row4 col1" >63</td>
#     </tr>
#     <tr>
#       <th id="T_f2bfa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f2bfa_row5_col0" class="data row5 col0" >Kings XI Punjab</td>
#       <td id="T_f2bfa_row5_col1" class="data row5 col1" >63</td>
#     </tr>
#     <tr>
#       <th id="T_f2bfa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f2bfa_row6_col0" class="data row6 col0" >Delhi Daredevils</td>
#       <td id="T_f2bfa_row6_col1" class="data row6 col1" >56</td>
#     </tr>
#     <tr>
#       <th id="T_f2bfa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f2bfa_row7_col0" class="data row7 col0" >Sunrisers Hyderabad</td>
#       <td id="T_f2bfa_row7_col1" class="data row7 col1" >34</td>
#     </tr>
#     <tr>
#       <th id="T_f2bfa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f2bfa_row8_col0" class="data row8 col0" >Deccan Chargers</td>
#       <td id="T_f2bfa_row8_col1" class="data row8 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_f2bfa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f2bfa_row9_col0" class="data row9 col0" >Pune Warriors</td>
#       <td id="T_f2bfa_row9_col1" class="data row9 col1" >12</td>
#     </tr>
#   </tbody>
# </table>

# %%
#9.Highest Wicket takers in IPL
sql=""" select Player_Name,count(Kind_Out) as Wickets,
        sum(case when Kind_Out==1 then 1 else 0 end) as caught,
        sum(case when Kind_Out==2 then 1 else 0 end) as bowled,
        sum(case when Kind_Out==4 then 1 else 0 end) as lbw,
        sum(case when Kind_Out==6 then 1 else 0 end) as stumped
        from Wicket_Taken a
        join Ball_by_Ball b
        on a.Match_Id=b.Match_Id 
        and a.Innings_No=b.Innings_No
        and a.Over_Id=b.Over_Id 
        and a.Ball_Id=b.Ball_Id
        join (select Player_Id,Player_Name,b.Country_Name, c.Bowling_skill
              from Player a
              join Country b
              on a.Country_Name=b.Country_Id
              join Bowling_Style c
              on a.Bowling_skill=c.Bowling_Id) c
        on b.Bowler=c.Player_Id
        where Kind_Out in (1,2,4,6,7,8)
        group by c.Player_Id
        order by Wickets desc; """

wickets=pd.read_sql(sql, conn)
subset=["Wickets","caught","bowled","lbw","stumped","caught and bowled"]
wickets.head().style.background_gradient(subset=["Wickets"],cmap="binary",low=0.25)
# Out:
# <style type="text/css">
# #T_6fa3c_row0_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_6fa3c_row1_col1 {
#   background-color: #a2a2a2;
#   color: #f1f1f1;
# }
# #T_6fa3c_row2_col1 {
#   background-color: #b3b3b3;
#   color: #000000;
# }
# #T_6fa3c_row3_col1 {
#   background-color: #c4c4c4;
#   color: #000000;
# }
# #T_6fa3c_row4_col1 {
#   background-color: #cccccc;
#   color: #000000;
# }
# </style>
# <table id="T_6fa3c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Wickets</th>
#       <th class="col_heading level0 col2" >caught</th>
#       <th class="col_heading level0 col3" >bowled</th>
#       <th class="col_heading level0 col4" >lbw</th>
#       <th class="col_heading level0 col5" >stumped</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fa3c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6fa3c_row0_col0" class="data row0 col0" >SL Malinga</td>
#       <td id="T_6fa3c_row0_col1" class="data row0 col1" >143</td>
#       <td id="T_6fa3c_row0_col2" class="data row0 col2" >69</td>
#       <td id="T_6fa3c_row0_col3" class="data row0 col3" >59</td>
#       <td id="T_6fa3c_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_6fa3c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6fa3c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6fa3c_row1_col0" class="data row1 col0" >A Mishra</td>
#       <td id="T_6fa3c_row1_col1" class="data row1 col1" >124</td>
#       <td id="T_6fa3c_row1_col2" class="data row1 col2" >66</td>
#       <td id="T_6fa3c_row1_col3" class="data row1 col3" >21</td>
#       <td id="T_6fa3c_row1_col4" class="data row1 col4" >13</td>
#       <td id="T_6fa3c_row1_col5" class="data row1 col5" >21</td>
#     </tr>
#     <tr>
#       <th id="T_6fa3c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6fa3c_row2_col0" class="data row2 col0" >DJ Bravo</td>
#       <td id="T_6fa3c_row2_col1" class="data row2 col1" >122</td>
#       <td id="T_6fa3c_row2_col2" class="data row2 col2" >90</td>
#       <td id="T_6fa3c_row2_col3" class="data row2 col3" >18</td>
#       <td id="T_6fa3c_row2_col4" class="data row2 col4" >6</td>
#       <td id="T_6fa3c_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6fa3c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6fa3c_row3_col0" class="data row3 col0" >PP Chawla</td>
#       <td id="T_6fa3c_row3_col1" class="data row3 col1" >120</td>
#       <td id="T_6fa3c_row3_col2" class="data row3 col2" >56</td>
#       <td id="T_6fa3c_row3_col3" class="data row3 col3" >33</td>
#       <td id="T_6fa3c_row3_col4" class="data row3 col4" >14</td>
#       <td id="T_6fa3c_row3_col5" class="data row3 col5" >13</td>
#     </tr>
#     <tr>
#       <th id="T_6fa3c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6fa3c_row4_col0" class="data row4 col0" >Harbhajan Singh</td>
#       <td id="T_6fa3c_row4_col1" class="data row4 col1" >119</td>
#       <td id="T_6fa3c_row4_col2" class="data row4 col2" >61</td>
#       <td id="T_6fa3c_row4_col3" class="data row4 col3" >25</td>
#       <td id="T_6fa3c_row4_col4" class="data row4 col4" >8</td>
#       <td id="T_6fa3c_row4_col5" class="data row4 col5" >14</td>
#     </tr>
#   </tbody>
# </table>

# %%
#10.Top 5 Run scorers¶
sql = """
select p.player_id,p.player_name,SUM(ba.Runs_Scored) as Total_Runs
from batsman_scored ba

JOIN Ball_by_ball bl
ON ba.Match_id = bl.Match_Id
   AND ba.Over_id = bl.Over_id
   AND ba.ball_id = bl.ball_id
   AND ba.Innings_No = bl.Innings_No
JOIN player p
ON p.player_id = bl.striker
Group by bl.Striker
ORDER BY SUM(ba.Runs_Scored) DESC
LIMIT 10
"""
runs_scorers = pd.read_sql(sql, conn)
runs_scorers.head(5).style.background_gradient(subset=["Total_Runs"], cmap='Oranges',low=0.55)
# Out:
# <style type="text/css">
# #T_2475d_row0_col2, #T_2475d_row1_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_2475d_row2_col2 {
#   background-color: #d04501;
#   color: #f1f1f1;
# }
# #T_2475d_row3_col2 {
#   background-color: #f98230;
#   color: #f1f1f1;
# }
# #T_2475d_row4_col2 {
#   background-color: #fdb475;
#   color: #000000;
# }
# </style>
# <table id="T_2475d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Id</th>
#       <th class="col_heading level0 col1" >Player_Name</th>
#       <th class="col_heading level0 col2" >Total_Runs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2475d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2475d_row0_col0" class="data row0 col0" >21</td>
#       <td id="T_2475d_row0_col1" class="data row0 col1" >SK Raina</td>
#       <td id="T_2475d_row0_col2" class="data row0 col2" >4106</td>
#     </tr>
#     <tr>
#       <th id="T_2475d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2475d_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_2475d_row1_col1" class="data row1 col1" >V Kohli</td>
#       <td id="T_2475d_row1_col2" class="data row1 col2" >4105</td>
#     </tr>
#     <tr>
#       <th id="T_2475d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2475d_row2_col0" class="data row2 col0" >57</td>
#       <td id="T_2475d_row2_col1" class="data row2 col1" >RG Sharma</td>
#       <td id="T_2475d_row2_col2" class="data row2 col2" >3874</td>
#     </tr>
#     <tr>
#       <th id="T_2475d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2475d_row3_col0" class="data row3 col0" >40</td>
#       <td id="T_2475d_row3_col1" class="data row3 col1" >G Gambhir</td>
#       <td id="T_2475d_row3_col2" class="data row3 col2" >3634</td>
#     </tr>
#     <tr>
#       <th id="T_2475d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2475d_row4_col0" class="data row4 col0" >162</td>
#       <td id="T_2475d_row4_col1" class="data row4 col1" >CH Gayle</td>
#       <td id="T_2475d_row4_col2" class="data row4 col2" >3447</td>
#     </tr>
#   </tbody>
# </table>

# %%
#11.Wicket types
sql="""
SELECT ot.Out_Name,COUNT(wt.Kind_Out) AS Wicket_types
FROM Wicket_Taken wt 
JOIN Out_Type ot
ON wt.Kind_Out=ot.Out_Id
GROUP BY ot.Out_Name
ORDER BY COUNT(wt.Kind_Out) DESC
"""
Wicket_types=pd.read_sql(sql,conn)
Wicket_types.style.background_gradient(subset=["Wicket_types"],cmap="cubehelix",low=0.25)
# Out:
# <style type="text/css">
# #T_157e6_row0_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_157e6_row1_col1 {
#   background-color: #7b7a35;
#   color: #f1f1f1;
# }
# #T_157e6_row2_col1 {
#   background-color: #2f7137;
#   color: #f1f1f1;
# }
# #T_157e6_row3_col1 {
#   background-color: #195e47;
#   color: #f1f1f1;
# }
# #T_157e6_row4_col1 {
#   background-color: #15504d;
#   color: #f1f1f1;
# }
# #T_157e6_row5_col1 {
#   background-color: #154d4e;
#   color: #f1f1f1;
# }
# #T_157e6_row6_col1, #T_157e6_row7_col1, #T_157e6_row8_col1 {
#   background-color: #163d4e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_157e6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Out_Name</th>
#       <th class="col_heading level0 col1" >Wicket_types</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_157e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_157e6_row0_col0" class="data row0 col0" >caught</td>
#       <td id="T_157e6_row0_col1" class="data row0 col1" >3954</td>
#     </tr>
#     <tr>
#       <th id="T_157e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_157e6_row1_col0" class="data row1 col0" >bowled</td>
#       <td id="T_157e6_row1_col1" class="data row1 col1" >1251</td>
#     </tr>
#     <tr>
#       <th id="T_157e6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_157e6_row2_col0" class="data row2 col0" >run out</td>
#       <td id="T_157e6_row2_col1" class="data row2 col1" >697</td>
#     </tr>
#     <tr>
#       <th id="T_157e6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_157e6_row3_col0" class="data row3 col0" >lbw</td>
#       <td id="T_157e6_row3_col1" class="data row3 col1" >399</td>
#     </tr>
#     <tr>
#       <th id="T_157e6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_157e6_row4_col0" class="data row4 col0" >stumped</td>
#       <td id="T_157e6_row4_col1" class="data row4 col1" >222</td>
#     </tr>
#     <tr>
#       <th id="T_157e6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_157e6_row5_col0" class="data row5 col0" >caught and bowled</td>
#       <td id="T_157e6_row5_col1" class="data row5 col1" >187</td>
#     </tr>
#     <tr>
#       <th id="T_157e6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_157e6_row6_col0" class="data row6 col0" >retired hurt</td>
#       <td id="T_157e6_row6_col1" class="data row6 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_157e6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_157e6_row7_col0" class="data row7 col0" >hit wicket</td>
#       <td id="T_157e6_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_157e6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_157e6_row8_col0" class="data row8 col0" >obstructing the field</td>
#       <td id="T_157e6_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
#12. Man of the Series, Purple Cap, Orange Cap winners in every season
sql="""
SELECT se.Season_Year,mos.Player_Name Man_of_the_Series,oc.Player_Name Orange_Cap,pc.Player_Name Purple_Cap
FROM Season se
JOIN Player mos ON mos.Player_Id=se.Man_of_the_Series
JOIN Player oc ON oc.Player_Id=se.Orange_Cap
JOIN Player pc ON pc.Player_Id=se.Purple_Cap
"""
Query=pd.read_sql(sql,conn)
Query.style.background_gradient(subset=["Season_Year"],cmap="summer",low=0.25)
# Out:
# <style type="text/css">
# #T_85717_row0_col0 {
#   background-color: #339966;
#   color: #f1f1f1;
# }
# #T_85717_row1_col0 {
#   background-color: #4ca666;
#   color: #f1f1f1;
# }
# #T_85717_row2_col0 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_85717_row3_col0 {
#   background-color: #80c066;
#   color: #000000;
# }
# #T_85717_row4_col0 {
#   background-color: #99cc66;
#   color: #000000;
# }
# #T_85717_row5_col0 {
#   background-color: #b3d966;
#   color: #000000;
# }
# #T_85717_row6_col0 {
#   background-color: #cce666;
#   color: #000000;
# }
# #T_85717_row7_col0 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_85717_row8_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# </style>
# <table id="T_85717_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Season_Year</th>
#       <th class="col_heading level0 col1" >Man_of_the_Series</th>
#       <th class="col_heading level0 col2" >Orange_Cap</th>
#       <th class="col_heading level0 col3" >Purple_Cap</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85717_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85717_row0_col0" class="data row0 col0" >2008</td>
#       <td id="T_85717_row0_col1" class="data row0 col1" >SR Watson</td>
#       <td id="T_85717_row0_col2" class="data row0 col2" >SE Marsh</td>
#       <td id="T_85717_row0_col3" class="data row0 col3" >Sohail Tanvir</td>
#     </tr>
#     <tr>
#       <th id="T_85717_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_85717_row1_col0" class="data row1 col0" >2009</td>
#       <td id="T_85717_row1_col1" class="data row1 col1" >AC Gilchrist</td>
#       <td id="T_85717_row1_col2" class="data row1 col2" >ML Hayden</td>
#       <td id="T_85717_row1_col3" class="data row1 col3" >RP Singh</td>
#     </tr>
#     <tr>
#       <th id="T_85717_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_85717_row2_col0" class="data row2 col0" >2010</td>
#       <td id="T_85717_row2_col1" class="data row2 col1" >SR Tendulkar</td>
#       <td id="T_85717_row2_col2" class="data row2 col2" >SR Tendulkar</td>
#       <td id="T_85717_row2_col3" class="data row2 col3" >PP Ojha</td>
#     </tr>
#     <tr>
#       <th id="T_85717_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_85717_row3_col0" class="data row3 col0" >2011</td>
#       <td id="T_85717_row3_col1" class="data row3 col1" >CH Gayle</td>
#       <td id="T_85717_row3_col2" class="data row3 col2" >CH Gayle</td>
#       <td id="T_85717_row3_col3" class="data row3 col3" >SL Malinga</td>
#     </tr>
#     <tr>
#       <th id="T_85717_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_85717_row4_col0" class="data row4 col0" >2012</td>
#       <td id="T_85717_row4_col1" class="data row4 col1" >SP Narine</td>
#       <td id="T_85717_row4_col2" class="data row4 col2" >CH Gayle</td>
#       <td id="T_85717_row4_col3" class="data row4 col3" >M Morkel</td>
#     </tr>
#     <tr>
#       <th id="T_85717_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_85717_row5_col0" class="data row5 col0" >2013</td>
#       <td id="T_85717_row5_col1" class="data row5 col1" >SR Watson</td>
#       <td id="T_85717_row5_col2" class="data row5 col2" >MEK Hussey</td>
#       <td id="T_85717_row5_col3" class="data row5 col3" >DJ Bravo</td>
#     </tr>
#     <tr>
#       <th id="T_85717_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_85717_row6_col0" class="data row6 col0" >2014</td>
#       <td id="T_85717_row6_col1" class="data row6 col1" >GJ Maxwell</td>
#       <td id="T_85717_row6_col2" class="data row6 col2" >RV Uthappa</td>
#       <td id="T_85717_row6_col3" class="data row6 col3" >MM Sharma</td>
#     </tr>
#     <tr>
#       <th id="T_85717_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_85717_row7_col0" class="data row7 col0" >2015</td>
#       <td id="T_85717_row7_col1" class="data row7 col1" >AD Russell</td>
#       <td id="T_85717_row7_col2" class="data row7 col2" >DA Warner</td>
#       <td id="T_85717_row7_col3" class="data row7 col3" >DJ Bravo</td>
#     </tr>
#     <tr>
#       <th id="T_85717_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_85717_row8_col0" class="data row8 col0" >2016</td>
#       <td id="T_85717_row8_col1" class="data row8 col1" >V Kohli</td>
#       <td id="T_85717_row8_col2" class="data row8 col2" >V Kohli</td>
#       <td id="T_85717_row8_col3" class="data row8 col3" >B Kumar</td>
#     </tr>
#   </tbody>
# </table>

# %%
 #13.total extras (wides, no-balls, etc.) conceded by each team in a specific season
sql="""
SELECT se.Season_Year,te.Team_Name,et.Extra_Name,COUNT(ex.Extra_Runs) AS Total_Extras
FROM Extra_Runs ex
JOIN Extra_Type et
ON ex.Extra_Type_Id=et.Extra_Id
JOIN Season se
JOIN Team te
GROUP BY se.Season_Year,te.Team_Name,et.Extra_Name
ORDER BY COUNT(ex.Extra_Runs) DESC;
"""
Total_Extras=pd.read_sql(sql,conn)
Total_Extras.sample(10).style.background_gradient(subset=["Total_Extras"],cmap="summer",low=0.25)
# Out:
# <style type="text/css">
# #T_5926e_row0_col3 {
#   background-color: #4fa766;
#   color: #f1f1f1;
# }
# #T_5926e_row1_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_5926e_row2_col3, #T_5926e_row6_col3, #T_5926e_row8_col3 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_5926e_row3_col3, #T_5926e_row5_col3, #T_5926e_row7_col3 {
#   background-color: #45a266;
#   color: #f1f1f1;
# }
# #T_5926e_row4_col3, #T_5926e_row9_col3 {
#   background-color: #339966;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5926e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Season_Year</th>
#       <th class="col_heading level0 col1" >Team_Name</th>
#       <th class="col_heading level0 col2" >Extra_Name</th>
#       <th class="col_heading level0 col3" >Total_Extras</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5926e_level0_row0" class="row_heading level0 row0" >249</th>
#       <td id="T_5926e_row0_col0" class="data row0 col0" >2009</td>
#       <td id="T_5926e_row0_col1" class="data row0 col1" >Delhi Daredevils</td>
#       <td id="T_5926e_row0_col2" class="data row0 col2" >noballs</td>
#       <td id="T_5926e_row0_col3" class="data row0 col3" >579</td>
#     </tr>
#     <tr>
#       <th id="T_5926e_level0_row1" class="row_heading level0 row1" >46</th>
#       <td id="T_5926e_row1_col0" class="data row1 col0" >2011</td>
#       <td id="T_5926e_row1_col1" class="data row1 col1" >Mumbai Indians</td>
#       <td id="T_5926e_row1_col2" class="data row1 col2" >wides</td>
#       <td id="T_5926e_row1_col3" class="data row1 col3" >4153</td>
#     </tr>
#     <tr>
#       <th id="T_5926e_level0_row2" class="row_heading level0 row2" >169</th>
#       <td id="T_5926e_row2_col0" class="data row2 col0" >2012</td>
#       <td id="T_5926e_row2_col1" class="data row2 col1" >Chennai Super Kings</td>
#       <td id="T_5926e_row2_col2" class="data row2 col2" >legbyes</td>
#       <td id="T_5926e_row2_col3" class="data row2 col3" >2357</td>
#     </tr>
#     <tr>
#       <th id="T_5926e_level0_row3" class="row_heading level0 row3" >391</th>
#       <td id="T_5926e_row3_col0" class="data row3 col0" >2011</td>
#       <td id="T_5926e_row3_col1" class="data row3 col1" >Deccan Chargers</td>
#       <td id="T_5926e_row3_col2" class="data row3 col2" >byes</td>
#       <td id="T_5926e_row3_col3" class="data row3 col3" >379</td>
#     </tr>
#     <tr>
#       <th id="T_5926e_level0_row4" class="row_heading level0 row4" >489</th>
#       <td id="T_5926e_row4_col0" class="data row4 col0" >2009</td>
#       <td id="T_5926e_row4_col1" class="data row4 col1" >Pune Warriors</td>
#       <td id="T_5926e_row4_col2" class="data row4 col2" >penalty</td>
#       <td id="T_5926e_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5926e_level0_row5" class="row_heading level0 row5" >395</th>
#       <td id="T_5926e_row5_col0" class="data row5 col0" >2011</td>
#       <td id="T_5926e_row5_col1" class="data row5 col1" >Kochi Tuskers Kerala</td>
#       <td id="T_5926e_row5_col2" class="data row5 col2" >byes</td>
#       <td id="T_5926e_row5_col3" class="data row5 col3" >379</td>
#     </tr>
#     <tr>
#       <th id="T_5926e_level0_row6" class="row_heading level0 row6" >202</th>
#       <td id="T_5926e_row6_col0" class="data row6 col0" >2014</td>
#       <td id="T_5926e_row6_col1" class="data row6 col1" >Mumbai Indians</td>
#       <td id="T_5926e_row6_col2" class="data row6 col2" >legbyes</td>
#       <td id="T_5926e_row6_col3" class="data row6 col3" >2357</td>
#     </tr>
#     <tr>
#       <th id="T_5926e_level0_row7" class="row_heading level0 row7" >402</th>
#       <td id="T_5926e_row7_col0" class="data row7 col0" >2011</td>
#       <td id="T_5926e_row7_col1" class="data row7 col1" >Sunrisers Hyderabad</td>
#       <td id="T_5926e_row7_col2" class="data row7 col2" >byes</td>
#       <td id="T_5926e_row7_col3" class="data row7 col3" >379</td>
#     </tr>
#     <tr>
#       <th id="T_5926e_level0_row8" class="row_heading level0 row8" >138</th>
#       <td id="T_5926e_row8_col0" class="data row8 col0" >2009</td>
#       <td id="T_5926e_row8_col1" class="data row8 col1" >Pune Warriors</td>
#       <td id="T_5926e_row8_col2" class="data row8 col2" >legbyes</td>
#       <td id="T_5926e_row8_col3" class="data row8 col3" >2357</td>
#     </tr>
#     <tr>
#       <th id="T_5926e_level0_row9" class="row_heading level0 row9" >533</th>
#       <td id="T_5926e_row9_col0" class="data row9 col0" >2013</td>
#       <td id="T_5926e_row9_col1" class="data row9 col1" >Chennai Super Kings</td>
#       <td id="T_5926e_row9_col2" class="data row9 col2" >penalty</td>
#       <td id="T_5926e_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
#14.the percentage of matches won by teams that choose to bat first after winning the toss.
sql="""SELECT
    T.Team_Name,
    COUNT(M.Match_Id) AS Total_Matches,
    SUM(CASE WHEN Toss.Toss_Name = 'bat' AND M.Match_Winner = T.Team_Id THEN 1 ELSE 0 END) AS Matches_Won,
    (SUM(CASE WHEN Toss.Toss_Name = 'bat' AND M.Match_Winner = T.Team_Id THEN 1.0 ELSE 0 END) / COUNT(M.Match_Id)) * 100 AS WinningPercentage
FROM
    Match AS M
JOIN
    Team AS T
ON
    M.Match_Winner = T.Team_Id
JOIN
    Toss_Decision AS Toss
ON
    M.Toss_Decide = Toss.Toss_Id
GROUP BY
    T.Team_Name
ORDER BY
    WinningPercentage DESC
    LIMIT 10

"""
Percentage_Won = pd.read_sql(sql, conn)
Percentage_Won.style.background_gradient(subset=["WinningPercentage"],cmap="Oranges",low=0.25)
# Out:
# <style type="text/css">
# #T_516fe_row0_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_516fe_row1_col3 {
#   background-color: #d04501;
#   color: #f1f1f1;
# }
# #T_516fe_row2_col3 {
#   background-color: #fd9344;
#   color: #000000;
# }
# #T_516fe_row3_col3 {
#   background-color: #fd9446;
#   color: #000000;
# }
# #T_516fe_row4_col3 {
#   background-color: #fd974a;
#   color: #000000;
# }
# #T_516fe_row5_col3 {
#   background-color: #fd984b;
#   color: #000000;
# }
# #T_516fe_row6_col3 {
#   background-color: #fd9d53;
#   color: #000000;
# }
# #T_516fe_row7_col3 {
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_516fe_row8_col3 {
#   background-color: #fdc088;
#   color: #000000;
# }
# #T_516fe_row9_col3 {
#   background-color: #fdd9b4;
#   color: #000000;
# }
# </style>
# <table id="T_516fe_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Team_Name</th>
#       <th class="col_heading level0 col1" >Total_Matches</th>
#       <th class="col_heading level0 col2" >Matches_Won</th>
#       <th class="col_heading level0 col3" >WinningPercentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_516fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_516fe_row0_col0" class="data row0 col0" >Pune Warriors</td>
#       <td id="T_516fe_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_516fe_row0_col2" class="data row0 col2" >9</td>
#       <td id="T_516fe_row0_col3" class="data row0 col3" >75.000000</td>
#     </tr>
#     <tr>
#       <th id="T_516fe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_516fe_row1_col0" class="data row1 col0" >Chennai Super Kings</td>
#       <td id="T_516fe_row1_col1" class="data row1 col1" >79</td>
#       <td id="T_516fe_row1_col2" class="data row1 col2" >50</td>
#       <td id="T_516fe_row1_col3" class="data row1 col3" >63.291139</td>
#     </tr>
#     <tr>
#       <th id="T_516fe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_516fe_row2_col0" class="data row2 col0" >Kolkata Knight Riders</td>
#       <td id="T_516fe_row2_col1" class="data row2 col1" >68</td>
#       <td id="T_516fe_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_516fe_row2_col3" class="data row2 col3" >48.529412</td>
#     </tr>
#     <tr>
#       <th id="T_516fe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_516fe_row3_col0" class="data row3 col0" >Deccan Chargers</td>
#       <td id="T_516fe_row3_col1" class="data row3 col1" >29</td>
#       <td id="T_516fe_row3_col2" class="data row3 col2" >14</td>
#       <td id="T_516fe_row3_col3" class="data row3 col3" >48.275862</td>
#     </tr>
#     <tr>
#       <th id="T_516fe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_516fe_row4_col0" class="data row4 col0" >Rajasthan Royals</td>
#       <td id="T_516fe_row4_col1" class="data row4 col1" >63</td>
#       <td id="T_516fe_row4_col2" class="data row4 col2" >30</td>
#       <td id="T_516fe_row4_col3" class="data row4 col3" >47.619048</td>
#     </tr>
#     <tr>
#       <th id="T_516fe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_516fe_row5_col0" class="data row5 col0" >Mumbai Indians</td>
#       <td id="T_516fe_row5_col1" class="data row5 col1" >80</td>
#       <td id="T_516fe_row5_col2" class="data row5 col2" >38</td>
#       <td id="T_516fe_row5_col3" class="data row5 col3" >47.500000</td>
#     </tr>
#     <tr>
#       <th id="T_516fe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_516fe_row6_col0" class="data row6 col0" >Delhi Daredevils</td>
#       <td id="T_516fe_row6_col1" class="data row6 col1" >56</td>
#       <td id="T_516fe_row6_col2" class="data row6 col2" >26</td>
#       <td id="T_516fe_row6_col3" class="data row6 col3" >46.428571</td>
#     </tr>
#     <tr>
#       <th id="T_516fe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_516fe_row7_col0" class="data row7 col0" >Sunrisers Hyderabad</td>
#       <td id="T_516fe_row7_col1" class="data row7 col1" >34</td>
#       <td id="T_516fe_row7_col2" class="data row7 col2" >14</td>
#       <td id="T_516fe_row7_col3" class="data row7 col3" >41.176471</td>
#     </tr>
#     <tr>
#       <th id="T_516fe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_516fe_row8_col0" class="data row8 col0" >Rising Pune Supergiants</td>
#       <td id="T_516fe_row8_col1" class="data row8 col1" >5</td>
#       <td id="T_516fe_row8_col2" class="data row8 col2" >2</td>
#       <td id="T_516fe_row8_col3" class="data row8 col3" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_516fe_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_516fe_row9_col0" class="data row9 col0" >Royal Challengers Bangalore</td>
#       <td id="T_516fe_row9_col1" class="data row9 col1" >70</td>
#       <td id="T_516fe_row9_col2" class="data row9 col2" >24</td>
#       <td id="T_516fe_row9_col3" class="data row9 col3" >34.285714</td>
#     </tr>
#   </tbody>
# </table>

# %%
#15.Players Who Played for Multiple Teams in Different Seasons:
sql="""
SELECT pl.Player_Name,GROUP_CONCAT(te.team_name) AS teams_played_for,se.Season_Year
FROM Team te
JOIN Match ma
ON te.Team_Id=ma.Match_Winner
JOIN Player pl
ON pl.Player_Id=ma.Man_of_the_Match
JOIN Season se 
ON se.Season_Id=ma.Season_Id
GROUP BY pl.Player_Name,se.Season_Year
ORDER BY GROUP_CONCAT(te.team_name)
"""

teams_played_for=pd.read_sql(sql,conn)
teams_played_for.sample(10)
# Out:
#       Player_Name                                   teams_played_for  \
# 340      R Dravid                        Royal Challengers Bangalore
# 344    RV Uthappa                        Royal Challengers Bangalore
# 355     JH Kallis  Royal Challengers Bangalore,Royal Challengers ...
# 45       DR Smith  Chennai Super Kings,Chennai Super Kings,Chenna...
# 168      SE Marsh  Kings XI Punjab,Kings XI Punjab,Kings XI Punja...
# 134      BA Bhatt                                    Kings XI Punjab
# 37       MS Dhoni            Chennai Super Kings,Chennai Super Kings
# 125  AC Gilchrist                                    Kings XI Punjab
# 26       SK Raina                                Chennai Super Kings
# 203     YK Pathan                              Kolkata Knight Riders
#
#      Season_Year
# 340         2009
# 344         2010
# 355         2009
# 45          2014
# 168         2008
# 134         2011
# 37          2008
# 125         2012
# 26          2011
# 203         2014

# %%
#16.No of fifties and centruies by a batsman in an IPL

sql=""" select Player_Name,Country_Name,
        sum(case when runs>=50 and runs<100 then 1 else 0 end) as fifties,
        sum(case when runs>=100 then 1 else 0 end) as centuries,
        max(runs) as highest_score
        from(select Striker,sum(Runs_Scored) as runs
             from Ball_by_Ball a
             join Batsman_Scored b
             on a.Match_Id=b.Match_Id 
             and a.Innings_No=b.Innings_No
             and a.Over_Id=b.Over_Id 
             and a.Ball_Id=b.Ball_Id
             group by Striker,a.Match_Id
             having runs>=50) a
        join (select Player_Id,Player_Name,b.Country_Name, c.Batting_hand
             from Player a
             join Country b
             on a.Country_Name=b.Country_Id
             join Batting_Style c
             on a.Batting_hand=c.Batting_Id) b
        on a.Striker=b.Player_Id
        group by Player_Id
        order by highest_score desc; """

best_player=pd.read_sql(sql, conn)
best_player.head(10).style.background_gradient(subset=["fifties","centuries","highest_score"],low=0.55,axis=0)
# Out:
# <style type="text/css">
# #T_105eb_row0_col2 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_105eb_row0_col3, #T_105eb_row0_col4, #T_105eb_row2_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_105eb_row1_col2 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_105eb_row1_col3, #T_105eb_row3_col3, #T_105eb_row4_col3 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_105eb_row1_col4 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_105eb_row2_col3 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_105eb_row2_col4 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_105eb_row3_col2 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_105eb_row3_col4 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_105eb_row4_col2 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_105eb_row4_col4 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_105eb_row5_col2, #T_105eb_row5_col3, #T_105eb_row6_col3, #T_105eb_row7_col3, #T_105eb_row8_col3, #T_105eb_row8_col4, #T_105eb_row9_col3, #T_105eb_row9_col4 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_105eb_row5_col4 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_105eb_row6_col2, #T_105eb_row9_col2 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_105eb_row6_col4 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_105eb_row7_col2 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_105eb_row7_col4 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_105eb_row8_col2 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_105eb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >fifties</th>
#       <th class="col_heading level0 col3" >centuries</th>
#       <th class="col_heading level0 col4" >highest_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_105eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_105eb_row0_col0" class="data row0 col0" >CH Gayle</td>
#       <td id="T_105eb_row0_col1" class="data row0 col1" >West Indies</td>
#       <td id="T_105eb_row0_col2" class="data row0 col2" >21</td>
#       <td id="T_105eb_row0_col3" class="data row0 col3" >5</td>
#       <td id="T_105eb_row0_col4" class="data row0 col4" >175</td>
#     </tr>
#     <tr>
#       <th id="T_105eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_105eb_row1_col0" class="data row1 col0" >BB McCullum</td>
#       <td id="T_105eb_row1_col1" class="data row1 col1" >New Zealand</td>
#       <td id="T_105eb_row1_col2" class="data row1 col2" >11</td>
#       <td id="T_105eb_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_105eb_row1_col4" class="data row1 col4" >158</td>
#     </tr>
#     <tr>
#       <th id="T_105eb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_105eb_row2_col0" class="data row2 col0" >AB de Villiers</td>
#       <td id="T_105eb_row2_col1" class="data row2 col1" >South Africa</td>
#       <td id="T_105eb_row2_col2" class="data row2 col2" >22</td>
#       <td id="T_105eb_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_105eb_row2_col4" class="data row2 col4" >133</td>
#     </tr>
#     <tr>
#       <th id="T_105eb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_105eb_row3_col0" class="data row3 col0" >M Vijay</td>
#       <td id="T_105eb_row3_col1" class="data row3 col1" >India</td>
#       <td id="T_105eb_row3_col2" class="data row3 col2" >13</td>
#       <td id="T_105eb_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_105eb_row3_col4" class="data row3 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_105eb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_105eb_row4_col0" class="data row4 col0" >V Sehwag</td>
#       <td id="T_105eb_row4_col1" class="data row4 col1" >India</td>
#       <td id="T_105eb_row4_col2" class="data row4 col2" >16</td>
#       <td id="T_105eb_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_105eb_row4_col4" class="data row4 col4" >122</td>
#     </tr>
#     <tr>
#       <th id="T_105eb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_105eb_row5_col0" class="data row5 col0" >PC Valthaty</td>
#       <td id="T_105eb_row5_col1" class="data row5 col1" >India</td>
#       <td id="T_105eb_row5_col2" class="data row5 col2" >2</td>
#       <td id="T_105eb_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_105eb_row5_col4" class="data row5 col4" >120</td>
#     </tr>
#     <tr>
#       <th id="T_105eb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_105eb_row6_col0" class="data row6 col0" >A Symonds</td>
#       <td id="T_105eb_row6_col1" class="data row6 col1" >Australia</td>
#       <td id="T_105eb_row6_col2" class="data row6 col2" >5</td>
#       <td id="T_105eb_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_105eb_row6_col4" class="data row6 col4" >117</td>
#     </tr>
#     <tr>
#       <th id="T_105eb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_105eb_row7_col0" class="data row7 col0" >MEK Hussey</td>
#       <td id="T_105eb_row7_col1" class="data row7 col1" >Australia</td>
#       <td id="T_105eb_row7_col2" class="data row7 col2" >15</td>
#       <td id="T_105eb_row7_col3" class="data row7 col3" >1</td>
#       <td id="T_105eb_row7_col4" class="data row7 col4" >116</td>
#     </tr>
#     <tr>
#       <th id="T_105eb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_105eb_row8_col0" class="data row8 col0" >SE Marsh</td>
#       <td id="T_105eb_row8_col1" class="data row8 col1" >Australia</td>
#       <td id="T_105eb_row8_col2" class="data row8 col2" >18</td>
#       <td id="T_105eb_row8_col3" class="data row8 col3" >1</td>
#       <td id="T_105eb_row8_col4" class="data row8 col4" >115</td>
#     </tr>
#     <tr>
#       <th id="T_105eb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_105eb_row9_col0" class="data row9 col0" >WP Saha</td>
#       <td id="T_105eb_row9_col1" class="data row9 col1" >India</td>
#       <td id="T_105eb_row9_col2" class="data row9 col2" >5</td>
#       <td id="T_105eb_row9_col3" class="data row9 col3" >1</td>
#       <td id="T_105eb_row9_col4" class="data row9 col4" >115</td>
#     </tr>
#   </tbody>
# </table>

# %%
#17.Numer of dissmissals by each wicket type
sql = """
select o.Out_Name AS Wicket_type, COUNT(w.Kind_Out) AS Total_dissmissals
from Out_Type o
JOIN Wicket_Taken w
ON o.Out_Id = w.Kind_Out
GROUP BY 1
ORDER BY Total_dissmissals DESC
"""
wickets = pd.read_sql(sql, conn)
wickets.style.background_gradient(subset=["Total_dissmissals"],cmap="Oranges",low=0.25)
# Out:
# <style type="text/css">
# #T_f55b5_row0_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_f55b5_row1_col1 {
#   background-color: #fd9a4e;
#   color: #000000;
# }
# #T_f55b5_row2_col1 {
#   background-color: #fdb77a;
#   color: #000000;
# }
# #T_f55b5_row3_col1 {
#   background-color: #fdc895;
#   color: #000000;
# }
# #T_f55b5_row4_col1 {
#   background-color: #fdd1a4;
#   color: #000000;
# }
# #T_f55b5_row5_col1 {
#   background-color: #fdd3a7;
#   color: #000000;
# }
# #T_f55b5_row6_col1, #T_f55b5_row7_col1, #T_f55b5_row8_col1 {
#   background-color: #fdd9b4;
#   color: #000000;
# }
# </style>
# <table id="T_f55b5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Wicket_type</th>
#       <th class="col_heading level0 col1" >Total_dissmissals</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f55b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f55b5_row0_col0" class="data row0 col0" >caught</td>
#       <td id="T_f55b5_row0_col1" class="data row0 col1" >3954</td>
#     </tr>
#     <tr>
#       <th id="T_f55b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f55b5_row1_col0" class="data row1 col0" >bowled</td>
#       <td id="T_f55b5_row1_col1" class="data row1 col1" >1251</td>
#     </tr>
#     <tr>
#       <th id="T_f55b5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f55b5_row2_col0" class="data row2 col0" >run out</td>
#       <td id="T_f55b5_row2_col1" class="data row2 col1" >697</td>
#     </tr>
#     <tr>
#       <th id="T_f55b5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f55b5_row3_col0" class="data row3 col0" >lbw</td>
#       <td id="T_f55b5_row3_col1" class="data row3 col1" >399</td>
#     </tr>
#     <tr>
#       <th id="T_f55b5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f55b5_row4_col0" class="data row4 col0" >stumped</td>
#       <td id="T_f55b5_row4_col1" class="data row4 col1" >222</td>
#     </tr>
#     <tr>
#       <th id="T_f55b5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f55b5_row5_col0" class="data row5 col0" >caught and bowled</td>
#       <td id="T_f55b5_row5_col1" class="data row5 col1" >187</td>
#     </tr>
#     <tr>
#       <th id="T_f55b5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f55b5_row6_col0" class="data row6 col0" >retired hurt</td>
#       <td id="T_f55b5_row6_col1" class="data row6 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_f55b5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f55b5_row7_col0" class="data row7 col0" >hit wicket</td>
#       <td id="T_f55b5_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_f55b5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f55b5_row8_col0" class="data row8 col0" >obstructing the field</td>
#       <td id="T_f55b5_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
#18. Total Number of Wickets Taken in Each Over

sql="""
SELECT Over_Id AS Over_Numbers, COUNT(Over_Id) As Wickets
FROM Wicket_Taken
GROUP BY Over_Id
ORDER BY COUNT(Over_Id) DESC
LIMIT 10
"""
Wickets=pd.read_sql(sql,conn)
Wickets.style.background_gradient(subset=["Wickets"],cmap="summer",low=0.25)
# Out:
# <style type="text/css">
# #T_db3c4_row0_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_db3c4_row1_col1 {
#   background-color: #b5da66;
#   color: #000000;
# }
# #T_db3c4_row2_col1 {
#   background-color: #a4d266;
#   color: #000000;
# }
# #T_db3c4_row3_col1 {
#   background-color: #71b866;
#   color: #f1f1f1;
# }
# #T_db3c4_row4_col1 {
#   background-color: #5dae66;
#   color: #f1f1f1;
# }
# #T_db3c4_row5_col1 {
#   background-color: #4ba566;
#   color: #f1f1f1;
# }
# #T_db3c4_row6_col1 {
#   background-color: #3e9e66;
#   color: #f1f1f1;
# }
# #T_db3c4_row7_col1 {
#   background-color: #359a66;
#   color: #f1f1f1;
# }
# #T_db3c4_row8_col1, #T_db3c4_row9_col1 {
#   background-color: #339966;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_db3c4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Over_Numbers</th>
#       <th class="col_heading level0 col1" >Wickets</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db3c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db3c4_row0_col0" class="data row0 col0" >20</td>
#       <td id="T_db3c4_row0_col1" class="data row0 col1" >678</td>
#     </tr>
#     <tr>
#       <th id="T_db3c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_db3c4_row1_col0" class="data row1 col0" >19</td>
#       <td id="T_db3c4_row1_col1" class="data row1 col1" >538</td>
#     </tr>
#     <tr>
#       <th id="T_db3c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_db3c4_row2_col0" class="data row2 col0" >18</td>
#       <td id="T_db3c4_row2_col1" class="data row2 col1" >506</td>
#     </tr>
#     <tr>
#       <th id="T_db3c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_db3c4_row3_col0" class="data row3 col0" >17</td>
#       <td id="T_db3c4_row3_col1" class="data row3 col1" >411</td>
#     </tr>
#     <tr>
#       <th id="T_db3c4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_db3c4_row4_col0" class="data row4 col0" >16</td>
#       <td id="T_db3c4_row4_col1" class="data row4 col1" >375</td>
#     </tr>
#     <tr>
#       <th id="T_db3c4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_db3c4_row5_col0" class="data row5 col0" >15</td>
#       <td id="T_db3c4_row5_col1" class="data row5 col1" >340</td>
#     </tr>
#     <tr>
#       <th id="T_db3c4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_db3c4_row6_col0" class="data row6 col0" >14</td>
#       <td id="T_db3c4_row6_col1" class="data row6 col1" >317</td>
#     </tr>
#     <tr>
#       <th id="T_db3c4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_db3c4_row7_col0" class="data row7 col0" >11</td>
#       <td id="T_db3c4_row7_col1" class="data row7 col1" >300</td>
#     </tr>
#     <tr>
#       <th id="T_db3c4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_db3c4_row8_col0" class="data row8 col0" >3</td>
#       <td id="T_db3c4_row8_col1" class="data row8 col1" >296</td>
#     </tr>
#     <tr>
#       <th id="T_db3c4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_db3c4_row9_col0" class="data row9 col0" >5</td>
#       <td id="T_db3c4_row9_col1" class="data row9 col1" >295</td>
#     </tr>
#   </tbody>
# </table>

# %%
#19.Win-Loss Statistics
sql = """
SELECT te.Team_Name,
       COUNT(ma.Match_Id) AS Total_Matches,
       SUM(CASE WHEN te.Team_Id = ma.Match_Winner THEN 1 ELSE 0 END) AS Wins,
       SUM(CASE WHEN te.Team_Id <> ma.Match_Winner THEN 1 ELSE 0 END) AS Losses,
       ROUND(SUM(CASE WHEN te.Team_Id = ma.Match_Winner THEN 1 ELSE 0 END)* 100.0 / COUNT(ma.Match_Id), 0) AS Wins_Percentage,       
       ROUND(SUM(CASE WHEN te.Team_Id <> ma.Match_Winner THEN 1 ELSE 0 END) * 100.0 /COUNT(ma.Match_Id), 0) AS Loss_Percentage
FROM Team te
JOIN Match ma 
ON te.Team_Id = ma.Match_Winner 
OR te.Team_Id = ma.Team_1 
OR te.Team_Id = ma.Team_2
GROUP BY te.Team_Name
ORDER BY Total_Matches DESC
LIMIT 10

"""
win_loss=pd.read_sql(sql,conn)
win_loss.style.background_gradient(subset=["Wins","Losses","Wins_Percentage","Loss_Percentage"],cmap="Blues",low=0.25)
# Out:
# <style type="text/css">
# #T_4e5b8_row0_col2, #T_4e5b8_row3_col3, #T_4e5b8_row5_col4, #T_4e5b8_row9_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4e5b8_row0_col3 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_4e5b8_row0_col4 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_4e5b8_row0_col5 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_4e5b8_row1_col2, #T_4e5b8_row8_col4 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_4e5b8_row1_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_4e5b8_row1_col4 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_4e5b8_row1_col5, #T_4e5b8_row4_col5, #T_4e5b8_row7_col2 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_4e5b8_row2_col2, #T_4e5b8_row6_col2 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_4e5b8_row2_col3 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_4e5b8_row2_col4 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_4e5b8_row2_col5 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_4e5b8_row3_col2 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_4e5b8_row3_col4 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_4e5b8_row3_col5 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_4e5b8_row4_col2 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_4e5b8_row4_col3 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_4e5b8_row4_col4 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_4e5b8_row5_col2 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_4e5b8_row5_col3 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_4e5b8_row5_col5, #T_4e5b8_row8_col3, #T_4e5b8_row9_col2, #T_4e5b8_row9_col4 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_4e5b8_row6_col3 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_4e5b8_row6_col4 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_4e5b8_row6_col5 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_4e5b8_row7_col3, #T_4e5b8_row7_col4 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_4e5b8_row7_col5 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_4e5b8_row8_col2 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_4e5b8_row8_col5 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_4e5b8_row9_col3 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# </style>
# <table id="T_4e5b8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Team_Name</th>
#       <th class="col_heading level0 col1" >Total_Matches</th>
#       <th class="col_heading level0 col2" >Wins</th>
#       <th class="col_heading level0 col3" >Losses</th>
#       <th class="col_heading level0 col4" >Wins_Percentage</th>
#       <th class="col_heading level0 col5" >Loss_Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e5b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e5b8_row0_col0" class="data row0 col0" >Mumbai Indians</td>
#       <td id="T_4e5b8_row0_col1" class="data row0 col1" >140</td>
#       <td id="T_4e5b8_row0_col2" class="data row0 col2" >80</td>
#       <td id="T_4e5b8_row0_col3" class="data row0 col3" >60</td>
#       <td id="T_4e5b8_row0_col4" class="data row0 col4" >57.000000</td>
#       <td id="T_4e5b8_row0_col5" class="data row0 col5" >43.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e5b8_row1_col0" class="data row1 col0" >Royal Challengers Bangalore</td>
#       <td id="T_4e5b8_row1_col1" class="data row1 col1" >139</td>
#       <td id="T_4e5b8_row1_col2" class="data row1 col2" >70</td>
#       <td id="T_4e5b8_row1_col3" class="data row1 col3" >67</td>
#       <td id="T_4e5b8_row1_col4" class="data row1 col4" >50.000000</td>
#       <td id="T_4e5b8_row1_col5" class="data row1 col5" >48.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5b8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4e5b8_row2_col0" class="data row2 col0" >Kings XI Punjab</td>
#       <td id="T_4e5b8_row2_col1" class="data row2 col1" >134</td>
#       <td id="T_4e5b8_row2_col2" class="data row2 col2" >63</td>
#       <td id="T_4e5b8_row2_col3" class="data row2 col3" >71</td>
#       <td id="T_4e5b8_row2_col4" class="data row2 col4" >47.000000</td>
#       <td id="T_4e5b8_row2_col5" class="data row2 col5" >53.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5b8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4e5b8_row3_col0" class="data row3 col0" >Delhi Daredevils</td>
#       <td id="T_4e5b8_row3_col1" class="data row3 col1" >133</td>
#       <td id="T_4e5b8_row3_col2" class="data row3 col2" >56</td>
#       <td id="T_4e5b8_row3_col3" class="data row3 col3" >75</td>
#       <td id="T_4e5b8_row3_col4" class="data row3 col4" >42.000000</td>
#       <td id="T_4e5b8_row3_col5" class="data row3 col5" >56.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5b8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4e5b8_row4_col0" class="data row4 col0" >Kolkata Knight Riders</td>
#       <td id="T_4e5b8_row4_col1" class="data row4 col1" >132</td>
#       <td id="T_4e5b8_row4_col2" class="data row4 col2" >68</td>
#       <td id="T_4e5b8_row4_col3" class="data row4 col3" >64</td>
#       <td id="T_4e5b8_row4_col4" class="data row4 col4" >52.000000</td>
#       <td id="T_4e5b8_row4_col5" class="data row4 col5" >48.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5b8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4e5b8_row5_col0" class="data row5 col0" >Chennai Super Kings</td>
#       <td id="T_4e5b8_row5_col1" class="data row5 col1" >131</td>
#       <td id="T_4e5b8_row5_col2" class="data row5 col2" >79</td>
#       <td id="T_4e5b8_row5_col3" class="data row5 col3" >52</td>
#       <td id="T_4e5b8_row5_col4" class="data row5 col4" >60.000000</td>
#       <td id="T_4e5b8_row5_col5" class="data row5 col5" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5b8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4e5b8_row6_col0" class="data row6 col0" >Rajasthan Royals</td>
#       <td id="T_4e5b8_row6_col1" class="data row6 col1" >118</td>
#       <td id="T_4e5b8_row6_col2" class="data row6 col2" >63</td>
#       <td id="T_4e5b8_row6_col3" class="data row6 col3" >54</td>
#       <td id="T_4e5b8_row6_col4" class="data row6 col4" >53.000000</td>
#       <td id="T_4e5b8_row6_col5" class="data row6 col5" >46.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5b8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4e5b8_row7_col0" class="data row7 col0" >Deccan Chargers</td>
#       <td id="T_4e5b8_row7_col1" class="data row7 col1" >75</td>
#       <td id="T_4e5b8_row7_col2" class="data row7 col2" >29</td>
#       <td id="T_4e5b8_row7_col3" class="data row7 col3" >46</td>
#       <td id="T_4e5b8_row7_col4" class="data row7 col4" >39.000000</td>
#       <td id="T_4e5b8_row7_col5" class="data row7 col5" >61.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5b8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4e5b8_row8_col0" class="data row8 col0" >Sunrisers Hyderabad</td>
#       <td id="T_4e5b8_row8_col1" class="data row8 col1" >62</td>
#       <td id="T_4e5b8_row8_col2" class="data row8 col2" >34</td>
#       <td id="T_4e5b8_row8_col3" class="data row8 col3" >28</td>
#       <td id="T_4e5b8_row8_col4" class="data row8 col4" >55.000000</td>
#       <td id="T_4e5b8_row8_col5" class="data row8 col5" >45.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4e5b8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4e5b8_row9_col0" class="data row9 col0" >Pune Warriors</td>
#       <td id="T_4e5b8_row9_col1" class="data row9 col1" >46</td>
#       <td id="T_4e5b8_row9_col2" class="data row9 col2" >12</td>
#       <td id="T_4e5b8_row9_col3" class="data row9 col3" >33</td>
#       <td id="T_4e5b8_row9_col4" class="data row9 col4" >26.000000</td>
#       <td id="T_4e5b8_row9_col5" class="data row9 col5" >72.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#20.Bowlers who have bowled most deliveries

sql="""SELECT Player_Name,c.Country_Name,d.Bowling_skill,count(*) as Deliveries
       FROM Ball_by_Ball a
       join Player b
       on a.Bowler==b.Player_Id
       join Country c
       on b.Country_Name==c.Country_Id
       join Bowling_Style d
       on b.Bowling_skill==d.Bowling_Id
       group by Bowler
       order by Deliveries desc ;"""

bowling=pd.read_sql(sql, conn)
bowling.head().style.background_gradient(subset=["Deliveries"],cmap="Reds",low=0.25)
# Out:
# <style type="text/css">
# #T_f818a_row0_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f818a_row1_col3 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_f818a_row2_col3 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_f818a_row3_col3 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_f818a_row4_col3 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# </style>
# <table id="T_f818a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Player_Name</th>
#       <th class="col_heading level0 col1" >Country_Name</th>
#       <th class="col_heading level0 col2" >Bowling_skill</th>
#       <th class="col_heading level0 col3" >Deliveries</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f818a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f818a_row0_col0" class="data row0 col0" >Harbhajan Singh</td>
#       <td id="T_f818a_row0_col1" class="data row0 col1" >India</td>
#       <td id="T_f818a_row0_col2" class="data row0 col2" >Right-arm offbreak</td>
#       <td id="T_f818a_row0_col3" class="data row0 col3" >2742</td>
#     </tr>
#     <tr>
#       <th id="T_f818a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f818a_row1_col0" class="data row1 col0" >P Kumar</td>
#       <td id="T_f818a_row1_col1" class="data row1 col1" >India</td>
#       <td id="T_f818a_row1_col2" class="data row1 col2" >Right-arm medium</td>
#       <td id="T_f818a_row1_col3" class="data row1 col3" >2529</td>
#     </tr>
#     <tr>
#       <th id="T_f818a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f818a_row2_col0" class="data row2 col0" >PP Chawla</td>
#       <td id="T_f818a_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_f818a_row2_col2" class="data row2 col2" >Legbreak</td>
#       <td id="T_f818a_row2_col3" class="data row2 col3" >2472</td>
#     </tr>
#     <tr>
#       <th id="T_f818a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f818a_row3_col0" class="data row3 col0" >A Mishra</td>
#       <td id="T_f818a_row3_col1" class="data row3 col1" >India</td>
#       <td id="T_f818a_row3_col2" class="data row3 col2" >Legbreak</td>
#       <td id="T_f818a_row3_col3" class="data row3 col3" >2466</td>
#     </tr>
#     <tr>
#       <th id="T_f818a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f818a_row4_col0" class="data row4 col0" >SL Malinga</td>
#       <td id="T_f818a_row4_col1" class="data row4 col1" >Sri Lanka</td>
#       <td id="T_f818a_row4_col2" class="data row4 col2" >Right-arm fast</td>
#       <td id="T_f818a_row4_col3" class="data row4 col3" >2407</td>
#     </tr>
#   </tbody>
# </table>
